# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

main_dish = pd.read_csv("main_dish.csv")
side_dish = pd.read_csv("side_dish.csv")
kimchi = pd.read_csv("removed_kimchi.csv")
rice = pd.read_csv("removed_rice.csv")
soup = pd.read_csv("removed_soup.csv")

MSRKS = [main_dish, side_dish,rice, kimchi, soup]
columns = [
    "RecipeID",
    "Name",
    "calories",
    "carbohydrate",
    "protein",
    "fat",
    "sugar",
    "sodium",
]
main_dish_dataset = main_dish[columns]
side_dish_dataset = side_dish[columns]
kimchi_dataset = kimchi[columns]
rice_dataset = rice[columns]
soup_dataset = soup[columns]

random_meal = []
for i in range(100):
    meal_list = [
        random.randint(1, len(main_dish_dataset)),
        random.randint(1, len(side_dish_dataset)),
        random.randint(1, len(rice_dataset)),
        random.randint(1, len(kimchi_dataset)),
        random.randint(1, len(soup_dataset)),
    ]
    random_meal.append(meal_list)

random_meal_nutrients = {
    "calories": [],
    "carbohydrate": [],
    "protein": [],
    "fat": [],
    "sugar": [],
    "sodium": [],
}
data_set_list = [
    main_dish_dataset,
    side_dish_dataset,
    rice_dataset,
    kimchi_dataset,
    soup_dataset,
] # 메인반찬, 사이드 반찬, 밥, 김치 , 국

for i in range(len(random_meal)):
    meal_nutrient_sum = {nutrient: 0 for nutrient in random_meal_nutrients}
    for j in range(5):
        recipe_id = random_meal[i][j]
        row = data_set_list[j][data_set_list[j]["RecipeID"] == recipe_id]
        if not row.empty:
            row = row.iloc[0]
            for nutrient in random_meal_nutrients:
                meal_nutrient_sum[nutrient] += row[nutrient]

    for nutrient in random_meal_nutrients:
        random_meal_nutrients[nutrient].append(meal_nutrient_sum[nutrient])

max_daily_Calories = 2700
max_daily_Carbohydrate = 325
max_daily_Protein = 200
max_daily_fat = 100
max_daily_Sugar = 40
max_daily_Sodium = 2400
max_list = [
    max_daily_Calories,
    max_daily_Carbohydrate,
    max_daily_Protein,
    max_daily_fat,
    max_daily_Sugar,
    max_daily_Sodium,
]

max_one_meal_Calories = 1500
max_one_meal_Carbohydrate = 200
max_one_meal_Protein = 120
max_one_meal_fat = 60
max_one_meal_Sugar = 30
max_one_meal_Sodium = 1600
max_one_meal_list = [
    max_one_meal_Calories,
    max_one_meal_Carbohydrate,
    max_one_meal_Protein,
    max_one_meal_fat,
    max_one_meal_Sugar,
    max_one_meal_Sodium,
]

filtered_random_meal = random_meal.copy()
for i in range(len(filtered_random_meal)):
    for j in range(6):
        if (
            random_meal_nutrients[list(random_meal_nutrients.keys())[j]][i]
            > max_one_meal_list[j]
        ):
            filtered_random_meal[i] = 0

filtered_random_meal = [i for i in filtered_random_meal if i != 0]

filtered_meal_nutrients = {nutrient: [] for nutrient in random_meal_nutrients}

for i in range(len(filtered_random_meal)):
    meal_nutrient_sum = {nutrient: 0 for nutrient in filtered_meal_nutrients}
    for j in range(5):
        recipe_id = filtered_random_meal[i][j]
        row = data_set_list[j][data_set_list[j]["RecipeID"] == recipe_id]
        if not row.empty:
            row = row.iloc[0]
            for nutrient in filtered_meal_nutrients:
                meal_nutrient_sum[nutrient] += row[nutrient]

    for nutrient in filtered_meal_nutrients:
        filtered_meal_nutrients[nutrient].append(meal_nutrient_sum[nutrient])

# 모델 개발
final_meal = pd.DataFrame()
final_meal["RecipeID"] = filtered_random_meal
for nutrient in filtered_meal_nutrients:
    final_meal[nutrient] = filtered_meal_nutrients[nutrient]

final_meal.to_csv("final_meal.csv")

day_meal = []

for i in range(1, len(final_meal) - 2):
    for j in range(i + 1, len(final_meal) - 1):
        for k in range(j + 1, len(final_meal)):
            meal_combination = [
                final_meal.iloc[i, :],
                final_meal.iloc[j, :],
                final_meal.iloc[k, :],
            ]
            day_meal.append(meal_combination)

closest_meal_combination = None
closest_distance = float("inf")

scaler = StandardScaler()

final_data = scaler.fit_transform(final_meal.iloc[:, 1:].to_numpy())

neigh = NearestNeighbors(metric="euclidean", algorithm="brute")
neigh.fit(final_data)

for meal_combination in day_meal:
    selected_meals_data = np.vstack([meal.iloc[1:].values for meal in meal_combination])
    selected_meals_data_scaled = scaler.transform(selected_meals_data)
    nearest_neighbors_indices = neigh.kneighbors(
        selected_meals_data_scaled, n_neighbors=1, return_distance=False
    )
    nearest_neighbor_index = nearest_neighbors_indices[0][0]
    nearest_neighbor_nutrients = final_meal.iloc[nearest_neighbor_index, 1:]
    selected_meals_nutrients_sum = {nutrient: 0 for nutrient in random_meal_nutrients}
    for meal in meal_combination:
        for nutrient in selected_meals_nutrients_sum:
            selected_meals_nutrients_sum[nutrient] += meal[nutrient]

    distance = np.linalg.norm(
        list(selected_meals_nutrients_sum.values()) - nearest_neighbor_nutrients
    )

    if distance < closest_distance and all(nearest_neighbor_nutrients <= max_list):
        closest_distance = distance
        closest_meal_combination = meal_combination

# %%
for i in range(5):
    print(MSRKS[i])
# Recipe_ID = []
# if closest_meal_combination is not None:
#     # print("\nSelected Meals:")
#     for i, meal in enumerate(closest_meal_combination):
#         # print(f"Meal {i + 1}:")
#         # print(meal)
#         for j in range(5):
#             if MSRKS[j]['RecipeID'] == meal[0][j]:
#                 print(k)
                
#     # print("\nRecommended Meal (Closest Neighbor):")
#     # print(final_meal.iloc[nearest_neighbor_index, :])
#     # print("-------------------------------")
# else:
#     print("다시 시도")
# Out:
#      RecipeID      Name 식품대분류  식품상세분류  1회제공량(g)  calories  carbohydrate  \
# 0           1     오징어순대    찜류    어패류찜       350    466.86         58.30
# 1           2       대구찜    찜류    어패류찜       500    376.42         24.70
# 2           3       동태찜    찜류    어패류찜       500    394.32         25.80
# 3           4    돼지등갈비찜    찜류     육류찜       450    961.04         57.40
# 4           5    돼지머리고기    찜류     육류찜       200    650.00          3.50
# ..        ...       ...   ...     ...       ...       ...           ...
# 197       198       콩조림   조림류  기타 조림류        30     84.27         10.45
# 198       199   곤약 감자조림   조림류   채소류조림        61     37.80          8.78
# 199       200      갈치조림   조림류   어패류조림       100    100.00          7.00
# 200       201     고등어조림   조림류   어패류조림       100    113.00          7.00
# 201       202  가자미두마리조림   조림류   어패류조림       100     99.00          7.00
#
#      protein    fat  sugar   sodium
# 0      45.70   5.60   0.40  1258.71
# 1      51.70   7.90   5.70  1898.67
# 2      50.90   9.70   5.70  1985.60
# 3      72.10  49.20  24.10  2395.17
# 4      42.40  52.00   0.10   333.64
# ..       ...    ...    ...      ...
# 197     5.39   2.32   1.06   260.31
# 198     0.64   0.01   0.00   305.00
# 199     9.00   4.00   3.00   321.00
# 200    10.00   5.00   3.00   310.00
# 201    11.00   2.50   3.00   378.00
#
# [202 rows x 11 columns]
#      RecipeID    Name    식품대분류    식품상세분류  1회제공량(g)  calories  carbohydrate  \
# 0           1   해파리냉채  생채및 무침류     어패류무침       150     91.00         13.40
# 1           2   골뱅이무침  생채및 무침류     어패류무침       100    108.79         15.69
# 2           3    노각무침  생채및 무침류  나물.채소류무침       150     84.00         14.30
# 3           4   단무지무침  생채및 무침류  나물.채소류무침        50     20.00          2.80
# 4           5  달래나물무침  생채및 무침류  나물.채소류무침       150    136.00         23.80
# ..        ...     ...      ...       ...       ...       ...           ...
# 146       147    김치만두  면 및 만두류       만두류       220    334.15         37.44
# 147       148      만두  면 및 만두류       만두류       220    397.27         39.79
# 148       149     물만두  면 및 만두류       만두류       230    448.16         35.90
# 149       150   야끼 만두  면 및 만두류       만두류        80    252.00         32.00
# 150       151    군 만두  면 및 만두류       만두류       180    528.00         44.00
#
#      protein    fat  sugar  sodium
# 0       6.20   1.40  11.40  508.77
# 1       7.08   1.97  10.46  525.52
# 2       2.60   1.80   7.10  817.37
# 3       0.50   0.80   0.70  428.92
# 4       4.00   2.80  11.20  867.04
# ..       ...    ...    ...     ...
# 146    22.53  10.47   0.77  865.26
# 147    19.05  17.99   0.00  800.92
# 148    18.53  25.60   4.89  763.59
# 149     4.00  12.00   2.00  124.00
# 150    16.00  32.00   3.00  710.00
#
# [151 rows x 11 columns]
#     RecipeID        Name 식품대분류   식품상세분류  1회제공량(g)  calories  carbohydrate  \
# 0          3       멍게비빔밥    밥류     비빔밥류       400    547.21         90.70
# 1          4          묵밥    밥류    기타 밥류       950    642.16        128.60
# 2          5         비빔밥    밥류     비빔밥류       450    691.62         98.70
# 3          6       삼선볶음밥    밥류     볶음밥류       400    686.11         85.75
# 4          7        송이덮밥    밥류      덮밥류       600    581.81         95.60
# 5          8       약초비빔밥    밥류     비빔밥류       400    511.80         80.20
# 6          9         오곡밥    밥류  쌀밥.잡곡밥류       250    388.82         82.32
# 7         10         자장밥    밥류      덮밥류       500    741.66        120.06
# 8         11         잡탕밥    밥류      덮밥류       750    777.44        104.94
# 9         12        장어덮밥    밥류      덮밥류       400    716.54         97.35
# 10        13        참치덮밥    밥류      덮밥류       500    679.10        102.93
# 11        14        해물덮밥    밥류      덮밥류       700    771.93        100.45
# 12        15       해물볶음밥    밥류     볶음밥류       400    705.22         90.46
# 13        16         회덮밥    밥류      덮밥류       500    683.02        103.30
# 14        17    BBQ갈비라이스    밥류     볶음밥류       371    567.00          0.00
# 15        18  치즈 불고기 도리아    밥류     볶음밥류       200    365.00          0.00
# 16        19        검정콩밥    밥류  쌀밥.잡곡밥류       200    330.61         68.59
# 17        20       계란볶음밥    밥류     볶음밥류       260    584.71         62.99
# 18        21         기장밥    밥류  쌀밥.잡곡밥류       200    331.91         73.53
# 19        22       김치볶음밥    밥류     볶음밥류       330    550.64         51.93
# 20        23        낙지덮밥    밥류      덮밥류       350    525.24         84.42
# 21        24       닭고기덮밥    밥류      덮밥류       410    510.58         60.77
# 22        25       돌솥비빔밥    밥류     비빔밥류       380    558.10         93.77
# 23        26       모듬회덮밥    밥류      덮밥류       410    593.54         72.80
# 24        27          무밥    밥류    기타 밥류       200    266.19         56.34
# 25        28         보리밥    밥류  쌀밥.잡곡밥류       200    321.63         73.54
# 26        29         볶음밥    밥류     볶음밥류       350    640.48        118.88
# 27        30       불고기덮밥    밥류      덮밥류       400    728.18        107.84
# 28        31         비빔밥    밥류     비빔밥류       450    637.54         84.76
# 29        32       새우볶음밥    밥류     볶음밥류       370    635.75         84.54
# 30        33      쇠고기볶음밥    밥류     볶음밥류       260    456.99         56.58
# 31        34         수수밥    밥류  쌀밥.잡곡밥류       200    321.89         70.04
# 32        35          알밥    밥류    기타 밥류       330    422.13         51.99
# 33        36       영양돌솥밥    밥류    기타 밥류       350    643.16        126.22
# 34        37       오므라이스    밥류     볶음밥류       400    692.71         82.14
# 35        38       오징어덮밥    밥류      덮밥류       360    484.59         79.00
# 36        39        완두콩밥    밥류  쌀밥.잡곡밥류       200    276.32         62.49
# 37        40       육회비빔밥    밥류     비빔밥류       300    442.29         68.76
# 38        41         잡곡밥    밥류  쌀밥.잡곡밥류       200    292.60         58.65
# 39        42         잡채밥    밥류      덮밥류       550    825.15        141.85
# 40        43        제육덮밥    밥류      덮밥류       470    949.76         79.22
# 41        44         짜장밥    밥류      덮밥류       470    572.62         73.17
# 42        45         차조밥    밥류  쌀밥.잡곡밥류       200    313.24         69.71
# 43        46          찰밥    밥류  쌀밥.잡곡밥류       280    429.70         93.97
# 44        47       참치볶음밥    밥류     볶음밥류       230    412.97         75.68
# 45        48       채소볶음밥    밥류     볶음밥류       260    474.03         74.73
# 46        49       카레라이스    밥류      덮밥류       480    518.40         99.53
# 47        50        콩나물밥    밥류    기타 밥류       320    392.17         71.66
# 48        51          팥밥    밥류  쌀밥.잡곡밥류       200    286.00         64.51
# 49        52     표고버섯볶음밥    밥류     볶음밥류       300    551.73         95.37
# 50        53       하이라이스    밥류      덮밥류       360    401.93         76.84
# 51        54         현미밥    밥류  쌀밥.잡곡밥류       230    396.31         89.48
# 52        55         흑미밥    밥류  쌀밥.잡곡밥류       200    348.70         80.14
# 53        56       새우필라프    밥류     볶음밥류       253    438.00         77.47
# 54        57      불고기필라프    밥류     볶음밥류       259    465.00         85.19
#
#     protein    fat  sugar   sodium
# 0     16.60  13.10  16.70  1144.80
# 1     14.80   7.70  15.10  2075.50
# 2     24.60  22.00  18.30  1119.66
# 3     26.24  26.46   1.58  1213.56
# 4     18.21  14.06   2.27  1678.01
# 5     11.90  15.90   2.90   971.61
# 6     11.95   1.30   0.17   113.90
# 7     15.24  22.28   5.37  1560.38
# 8     44.12  20.13   0.48  2109.52
# 9     30.09  22.98   5.59   920.77
# 10    29.20  16.73   2.98  1618.74
# 11    42.04  22.44   1.19  1802.68
# 12    25.10  27.00   1.22  1074.35
# 13    30.21  16.55  10.93   744.27
# 14    25.00   0.00  16.00  1203.00
# 15    11.00   0.00   5.00   540.00
# 16     9.06   2.23   0.00     6.87
# 17    17.22  29.32   0.44   827.60
# 18     6.87   1.14   0.00     2.79
# 19    17.56  30.30  45.85  1549.80
# 20    20.58  11.69   7.55   743.31
# 21    46.75   8.94   4.39   626.21
# 22    20.50  11.22   4.73  1281.83
# 23    37.32  17.01  12.57   634.31
# 24     7.33   1.28   0.00   554.22
# 25     5.80   0.48   5.14     7.85
# 26    19.47   9.67   0.00   743.58
# 27    26.39  21.25   0.28  1011.43
# 28    30.89  19.44   0.22  1041.85
# 29    23.33  22.70   2.63   538.64
# 30    19.74  16.86   0.22   560.18
# 31     6.31   1.83   0.15     2.55
# 32    15.61  16.86   7.60  1418.08
# 33    12.02  10.03   2.22    21.94
# 34    25.98  28.91  12.76  1730.11
# 35    25.85   7.24   2.37   582.23
# 36     5.89   0.31   0.00   590.06
# 37    19.16  10.07  13.36  1337.23
# 38    10.59   1.74   0.64     5.29
# 39    22.11  18.81   0.30  1247.22
# 40    44.30  50.63   9.30   819.84
# 41    20.08  22.18   0.16  1109.91
# 42     5.67   1.30   0.07     2.81
# 43    12.30   0.51   1.37     9.35
# 44    10.63   7.52   0.27  1450.92
# 45    12.26  14.01   0.76  1060.34
# 46    14.94   6.73   0.78  1007.05
# 47    14.98   5.07   0.12   868.99
# 48     6.56   0.19   0.00     7.12
# 49    10.09  14.43   0.00   896.57
# 50    14.47   4.08   0.00   884.09
# 51     7.14   1.09   0.00     4.80
# 52     6.53   0.22   0.04     3.51
# 53     9.72   9.56   1.85   754.55
# 54    11.42   9.25   3.16  1062.18
#     RecipeID       Name 식품대분류 식품상세분류  X1회제공량.g.  calories  carbohydrate  \
# 0        1.0       고들빼기   김치류     김치         50     55.53         10.93
# 1        2.0    열무얼갈이김치   김치류     김치         50     17.68          2.61
# 2        3.0        갓김치   김치류     김치         40     16.53          1.88
# 3        4.0     고들빼기김치   김치류     김치         50     35.27          5.76
# 4        5.0        깍두기   김치류     김치         50     16.40          2.12
# 5        6.0       깻잎김치   김치류     김치         50     31.15          4.46
# 6        7.0       나박김치   김치류     김치        100      9.82          1.15
# 7        8.0     돌나물물김치   김치류     김치        400     19.78          3.00
# 8        9.0        동치미   김치류     김치        200     27.21          4.55
# 9       10.0       배추김치   김치류     김치         40     10.66          1.27
# 10      11.0        백김치   김치류     김치         90     16.56          2.06
# 11      12.0       보쌈김치   김치류     김치         90     27.21          3.36
# 12      13.0       부추김치   김치류     김치         50     23.33          3.18
# 13      14.0    얼갈이배추김치   김치류     김치         80     50.46          8.75
# 14      15.0       열무김치   김치류     김치         40     10.71          0.86
# 15      16.0       오이김치   김치류     김치         70     26.54          3.95
# 16      17.0      오이소박이   김치류     김치        100     32.38          4.43
# 17      18.0       총각김치   김치류     김치         70     22.89          3.57
# 18      19.0        파김치   김치류     김치         30     13.32          1.26
# 19      20.0     무염 겉절이   김치류     김치         32     11.96          2.53
# 20      21.0     저염 겉절이   김치류     김치         33     13.11          2.05
# 21      22.0     고구마 김치   김치류     김치         62     95.86         22.44
# 22      23.0      배 깍두기   김치류     김치         56     31.66          6.33
# 23      24.0    콜라비 깍두기   김치류     김치         63     40.67          6.12
# 24      25.0  비타 오이 물김치   김치류     김치         55     13.46          2.99
# 25      26.0    무말랭이 김치   김치류     김치         35     10.86          2.56
#
#     protein   fat  sugar  sodium
# 0      1.58  0.61   2.84  742.43
# 1      1.07  0.33   0.46  339.90
# 2      1.03  0.54   0.47  175.22
# 3      1.50  0.69   2.20  302.71
# 4      0.78  0.53   1.27  403.75
# 5      1.41  0.86   2.02  462.03
# 6      0.46  0.38   0.34  377.45
# 7      1.25  0.31   1.40  949.46
# 8      0.58  0.74   2.90  823.74
# 9      0.68  0.31   0.95  123.03
# 10     0.92  0.51   0.70  402.65
# 11     1.97  0.65   1.52  595.04
# 12     1.34  0.58   2.04  380.66
# 13     1.27  1.16   0.30  196.87
# 14     0.72  0.49   0.17  194.47
# 15     1.44  0.56   1.66  326.04
# 16     1.73  0.86   3.40  541.03
# 17     0.98  0.52   1.34  332.00
# 18     0.77  0.58   0.45  259.16
# 19     0.45  0.01   0.00    1.67
# 20     0.72  0.23   0.00  215.66
# 21     0.91  0.27   0.00    1.44
# 22     0.72  0.39   0.00  284.48
# 23     2.07  0.88   0.00  378.32
# 24     0.34  0.02   0.00   30.88
# 25     0.14  0.00   0.00    1.85
#      RecipeID         Name     식품대분류    식품상세분류  1회제공량  calories  carbohydrate  \
# 0           1          게국지    국 및 탕류    어패류국.탕    100     37.75          2.88
# 1           2          곰치국    국 및 탕류    어패류국.탕    100     41.93          2.39
# 2           3          굴국밥    국 및 탕류    어패류국.탕    100    105.08         13.60
# 3           4          김치국    국 및 탕류    채소류국.탕    100     19.78          2.33
# 4           5         떡만둣국    국 및 탕류     기타 국류    100     89.27         15.82
# ..        ...          ...       ...       ...    ...       ...           ...
# 182       183  구수한 버섯 된장찌개  찌개 및 전골류  채소류찌개.전골    100     74.00          9.00
# 183       184    햄치즈 순두부찌개  찌개 및 전골류   육류찌개.전골    100     89.00          4.00
# 184       185     햄가득 부대전골  찌개 및 전골류   육류찌개.전골    100    208.00          7.00
# 185       186    짬뽕 순두부 찌개  찌개 및 전골류  채소류찌개.전골    100    114.00          8.00
# 186       187    우삼겹 청국장찌개  찌개 및 전골류   육류찌개.전골    100    116.00          4.00
#
#      protein    fat  sugar  sodium
# 0       4.08   1.10   0.98  367.93
# 1       5.43   1.18   0.28  380.21
# 2       6.52   2.74   0.05  251.60
# 3       1.20   0.62   0.64  364.91
# 4       2.87   1.62   0.02  282.88
# ..       ...    ...    ...     ...
# 182     5.00   1.60   3.00  698.00
# 183     7.00   5.00   1.00  476.00
# 184     9.00  16.00   1.00  844.00
# 185     7.00   6.00   1.00  784.00
# 186     7.00   8.00   0.00  354.00
#
# [187 rows x 11 columns]
